# %%
from google.api_core import page_iterator
import tensorflow as tf
from keras import datasets, layers, models
import google
from google.cloud import storage
import numpy as np
import sys
import os
from tensorflow.python.lib.io import file_io
from io import StringIO, BytesIO

# %%
def authenticate_remote():
    """
    Method to authenticate to GSC
    :return: None or error
    """
    if sys.platform == "linux":
        os.environ['GOOGLE_APPLICATION_CREDENTIALS'] = "../../keys/forestbiomass-key-epoch.json"
    elif sys.platform.startswith("win"):
        os.environ['GOOGLE_APPLICATION_CREDENTIALS'] = "../../keys/forestbiomass-key-epoch.json"

    try:
        storage.Client()
        return

    except google.auth.exceptions.DefaultCredentialsError as e:
        return e

# %%
authenticate_remote()

storage_client = storage.Client()
bucket = storage_client.bucket("forest-biomass")

# %%
label = bucket.blob("forest/0029317e/11/S2/10.npy")
label = BytesIO(label.download_as_string())
# Out:
# ---------------------------------------------------------------------------
# InvalidResponse                           Traceback (most recent call last)
# File ~\PycharmProjects\citylearn-2022-starter-kit\forestbiomass\lib\site-packages\google\cloud\storage\client.py:1079, in Client.download_blob_to_file(self, blob_or_uri, file_obj, start, end, raw_download, if_etag_match, if_etag_not_match, if_generation_match, if_generation_not_match, if_metageneration_match, if_metageneration_not_match, timeout, checksum, retry)
#    1078 try:
# -> 1079     blob_or_uri._do_download(
#    1080         transport,
#    1081         file_obj,
#    1082         download_url,
#    1083         headers,
#    1084         start,
#    1085         end,
#    1086         raw_download,
#    1087         timeout=timeout,
#    1088         checksum=checksum,
#    1089         retry=retry,
#    1090     )
#    1091 except resumable_media.InvalidResponse as exc:
#
# File ~\PycharmProjects\citylearn-2022-starter-kit\forestbiomass\lib\site-packages\google\cloud\storage\blob.py:984, in Blob._do_download(self, transport, file_obj, download_url, headers, start, end, raw_download, timeout, checksum, retry)
#     983 download._retry_strategy = retry_strategy
# --> 984 response = download.consume(transport, timeout=timeout)
#     985 self._extract_headers_from_download(response)
#
# File ~\PycharmProjects\citylearn-2022-starter-kit\forestbiomass\lib\site-packages\google\resumable_media\requests\download.py:232, in Download.consume(self, transport, timeout)
#     230     return result
# --> 232 return _request_helpers.wait_and_retry(
#     233     retriable_request, self._get_status_code, self._retry_strategy
#     234 )
#
# File ~\PycharmProjects\citylearn-2022-starter-kit\forestbiomass\lib\site-packages\google\resumable_media\requests\_request_helpers.py:148, in wait_and_retry(func, get_status_code, retry_strategy)
#     147 try:
# --> 148     response = func()
#     149 except _CONNECTION_ERROR_CLASSES as e:
#
# File ~\PycharmProjects\citylearn-2022-starter-kit\forestbiomass\lib\site-packages\google\resumable_media\requests\download.py:214, in Download.consume.<locals>.retriable_request()
#     210     self._object_generation = _helpers._parse_generation_header(
#     211         result, self._get_headers
#     212     )
# --> 214 self._process_response(result)
#     216 # With decompressive transcoding, GCS serves back the whole file regardless of the range request,
#     217 # thus we reset the stream position to the start of the stream.
#     218 # See: https://cloud.google.com/storage/docs/transcoding#range
#
# File ~\PycharmProjects\citylearn-2022-starter-kit\forestbiomass\lib\site-packages\google\resumable_media\_download.py:188, in Download._process_response(self, response)
#     187 self._finished = True
# --> 188 _helpers.require_status_code(
#     189     response, _ACCEPTABLE_STATUS_CODES, self._get_status_code
#     190 )
#
# File ~\PycharmProjects\citylearn-2022-starter-kit\forestbiomass\lib\site-packages\google\resumable_media\_helpers.py:108, in require_status_code(response, status_codes, get_status_code, callback)
#     107         callback()
# --> 108     raise common.InvalidResponse(
#     109         response,
#     110         "Request failed with status code",
#     111         status_code,
#     112         "Expected one of",
#     113         *status_codes
#     114     )
#     115 return status_code
#
# InvalidResponse: ('Request failed with status code', 404, 'Expected one of', <HTTPStatus.OK: 200>, <HTTPStatus.PARTIAL_CONTENT: 206>)
#
# During handling of the above exception, another exception occurred:
#
# NotFound                                  Traceback (most recent call last)
# Cell In [19], line 2
#       1 label = bucket.blob("forest/0029317e/11/S2/11.npy")
# ----> 2 label = BytesIO(label.download_as_string())
#
# File ~\PycharmProjects\citylearn-2022-starter-kit\forestbiomass\lib\site-packages\google\cloud\storage\blob.py:1502, in Blob.download_as_string(self, client, start, end, raw_download, if_etag_match, if_etag_not_match, if_generation_match, if_generation_not_match, if_metageneration_match, if_metageneration_not_match, timeout, retry)
#    1420 """(Deprecated) Download the contents of this blob as a bytes object.
#    1421
#    1422 If :attr:`user_project` is set on the bucket, bills the API request
#    (...)
#    1497 :raises: :class:`google.cloud.exceptions.NotFound`
#    1498 """
#    1499 warnings.warn(
#    1500     _DOWNLOAD_AS_STRING_DEPRECATED, PendingDeprecationWarning, stacklevel=2
#    1501 )
# -> 1502 return self.download_as_bytes(
#    1503     client=client,
#    1504     start=start,
#    1505     end=end,
#    1506     raw_download=raw_download,
#    1507     if_etag_match=if_etag_match,
#    1508     if_etag_not_match=if_etag_not_match,
#    1509     if_generation_match=if_generation_match,
#    1510     if_generation_not_match=if_generation_not_match,
#    1511     if_metageneration_match=if_metageneration_match,
#    1512     if_metageneration_not_match=if_metageneration_not_match,
#    1513     timeout=timeout,
#    1514     retry=retry,
#    1515 )
#
# File ~\PycharmProjects\citylearn-2022-starter-kit\forestbiomass\lib\site-packages\google\cloud\storage\blob.py:1387, in Blob.download_as_bytes(self, client, start, end, raw_download, if_etag_match, if_etag_not_match, if_generation_match, if_generation_not_match, if_metageneration_match, if_metageneration_not_match, timeout, checksum, retry)
#    1385 client = self._require_client(client)
#    1386 string_buffer = BytesIO()
# -> 1387 client.download_blob_to_file(
#    1388     self,
#    1389     string_buffer,
#    1390     start=start,
#    1391     end=end,
#    1392     raw_download=raw_download,
#    1393     if_etag_match=if_etag_match,
#    1394     if_etag_not_match=if_etag_not_match,
#    1395     if_generation_match=if_generation_match,
#    1396     if_generation_not_match=if_generation_not_match,
#    1397     if_metageneration_match=if_metageneration_match,
#    1398     if_metageneration_not_match=if_metageneration_not_match,
#    1399     timeout=timeout,
#    1400     checksum=checksum,
#    1401     retry=retry,
#    1402 )
#    1403 return string_buffer.getvalue()
#
# File ~\PycharmProjects\citylearn-2022-starter-kit\forestbiomass\lib\site-packages\google\cloud\storage\client.py:1092, in Client.download_blob_to_file(self, blob_or_uri, file_obj, start, end, raw_download, if_etag_match, if_etag_not_match, if_generation_match, if_generation_not_match, if_metageneration_match, if_metageneration_not_match, timeout, checksum, retry)
#    1079     blob_or_uri._do_download(
#    1080         transport,
#    1081         file_obj,
#    (...)
#    1089         retry=retry,
#    1090     )
#    1091 except resumable_media.InvalidResponse as exc:
# -> 1092     _raise_from_invalid_response(exc)
#
# File ~\PycharmProjects\citylearn-2022-starter-kit\forestbiomass\lib\site-packages\google\cloud\storage\blob.py:4368, in _raise_from_invalid_response(error)
#    4364     error_message = str(error)
#    4366 message = f"{response.request.method} {response.request.url}: {error_message}"
# -> 4368 raise exceptions.from_http_status(response.status_code, message, response=response)
#
# NotFound: 404 GET https://storage.googleapis.com/download/storage/v1/b/forest-biomass/o/forest%2F0029317e%2F11%2FS2%2F11.npy?alt=media: No such object: forest-biomass/forest/0029317e/11/S2/11.npy: ('Request failed with status code', 404, 'Expected one of', <HTTPStatus.OK: 200>, <HTTPStatus.PARTIAL_CONTENT: 206>)

# %%
print(np.load(label,allow_pickle=True))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In [17], line 1
# ----> 1 print(np.load(label,allow_pickle=True))
#
# File ~\PycharmProjects\citylearn-2022-starter-kit\forestbiomass\lib\site-packages\numpy\lib\npyio.py:390, in load(file, mmap_mode, allow_pickle, fix_imports, encoding)
#     388     own_fid = False
#     389 else:
# --> 390     fid = stack.enter_context(open(os_fspath(file), "rb"))
#     391     own_fid = True
#     393 # Code to distinguish from NumPy binary files and pickles.
#
# TypeError: expected str, bytes or os.PathLike object, not Blob

# %%
000aa810, 000d7e33,
