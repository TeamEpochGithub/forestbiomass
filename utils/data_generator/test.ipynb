# %%
from google.api_core import page_iterator
import tensorflow as tf
from keras import datasets, layers, models
import google
from google.cloud import storage
import numpy as np
import sys
import os
from tensorflow.python.lib.io import file_io
from io import StringIO, BytesIO

# %%
bucket_path = "gs://biomass-data/001eb75a/label.npy"

# %%
f = BytesIO(file_io.read_file_to_string(bucket_path, binary_mode=True))
# arr = np.load(f)
# arr
# Out:
# ---------------------------------------------------------------------------
# UnimplementedError                        Traceback (most recent call last)
# Cell In [3], line 1
# ----> 1 f = BytesIO(file_io.read_file_to_string(bucket_path, binary_mode=True))
#       2 # arr = np.load(f)
#       3 # arr
#
# File ~\PycharmProjects\citylearn-2022-starter-kit\forestbiomass\lib\site-packages\tensorflow\python\lib\io\file_io.py:349, in read_file_to_string(filename, binary_mode)
#     347 else:
#     348   f = FileIO(filename, mode="r")
# --> 349 return f.read()
#
# File ~\PycharmProjects\citylearn-2022-starter-kit\forestbiomass\lib\site-packages\tensorflow\python\lib\io\file_io.py:114, in FileIO.read(self, n)
#     102 def read(self, n=-1):
#     103   """Returns the contents of a file as a string.
#     104
#     105   Starts reading from current position in file.
#    (...)
#     112     string if in string (regular) mode.
#     113   """
# --> 114   self._preread_check()
#     115   if n == -1:
#     116     length = self.size() - self.tell()
#
# File ~\PycharmProjects\citylearn-2022-starter-kit\forestbiomass\lib\site-packages\tensorflow\python\lib\io\file_io.py:76, in FileIO._preread_check(self)
#      73 if not self._read_check_passed:
#      74   raise errors.PermissionDeniedError(None, None,
#      75                                      "File isn't open for reading")
# ---> 76 self._read_buf = _pywrap_file_io.BufferedInputStream(
#      77     compat.path_to_str(self.__name), 1024 * 512)
#
# UnimplementedError: File system scheme 'gs' not implemented (file: 'gs://biomass-data/001eb75a/label.npy')
