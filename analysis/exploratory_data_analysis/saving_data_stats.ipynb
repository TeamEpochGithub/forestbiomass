# %%
len([-14.265666,-22.645868,-14.094492,-22.631937,7436.289,6519.915,6846.0103,7228.104,7074.4814,6804.398,6688.6523,6697.9316,780.82544,880.34814,2.3171234])
# Out:
# 15

# %%
import csv
import numpy as np

# Load the CSV file
with open('band_stds.csv', 'r') as file:
    reader = csv.reader(file)
    data = [row for row in reader]
    n_cols = len(data[0])
    data = [row for row in data if len(row) == n_cols]

# Convert the data to a numpy array
data = np.array(data).astype(float)

# %%
# Calculate the column-wise means
means = np.mean(data, axis=0)

# %%
list(means)
# Out:
# [2.3706742546317616,
#  3.1754221078376057,
#  2.077109999336178,
#  2.7644115411788692,
#  1087.0125115153648,
#  1059.237538387056,
#  1099.622198615195,
#  1110.2871963523585,
#  1143.6329427935093,
#  1136.2581148387092,
#  1216.1541661034505,
#  1121.5768866409626,
#  469.8380424441332,
#  375.74263912577607,
#  8.487788505379974]
